# %%
import numpy as np

# %%
class LinearRegression():
    def __init__(self, learning_rate=0.01, n_iter=1000):
        self.bias= None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def fit(self, X, y):
        #step1
        m, n = X.shape
        self.bias = 0
        self.weights = np.zeros(n)

        # Gradient Descent
        for i in range(self.n_iter):
            #step2
            y_pred = self.bias + np.dot(X, self.weights)
    
            #step3
            db = (1/m) * np.sum(y_pred-y)
            dw = (1/m) * np.dot(X.T, (y_pred-y))
    
            #step4
            self.bias -= self.lr * db
            self.weights -= self.lr * dw

    def predict(self, X):
        y_pred = self.bias + np.dot(X, self.weights)
        return y_pred

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])

model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
print(y_pred)
print(model.bias)
print(model.weights)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]
# 0.09475321533750963
# [1.97375488]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x=X.flatten(), y=y, label='Actual', marker='o')
sns.lineplot(x=X.flatten(), y=y_pred, label='Predicted', marker='x', linestyle='--')

# Add grid and labels
plt.grid(True)
plt.xlabel('X Value')
plt.ylabel('y Value')
plt.title('Actual vs Predicted')
plt.legend() # Displays the labels defined above

plt.show()
