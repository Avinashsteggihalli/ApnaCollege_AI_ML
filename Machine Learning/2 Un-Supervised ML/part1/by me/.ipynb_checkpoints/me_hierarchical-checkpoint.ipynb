# %%
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# %%
iris = load_iris()

X = iris.data
y = iris.target

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
sns.scatterplot(x=X[:,0], y=X[:,2])
# Out:
# <Axes: >

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

Z = linkage(X_scaled, method="ward")

plt.figure(figsize=(12,6))
dendrogram(Z)
plt.xlabel("sample")
plt.ylabel("distance")
plt.title("Dendrogram of Hierrchical Clustering")
# Out:
# Text(0.5, 1.0, 'Dendrogram of Hierrchical Clustering')

# %%
hier_agg = AgglomerativeClustering(n_clusters=3)

labels = hier_agg.fit_predict(X_scaled)

sns.scatterplot(x=X[:,0], y=X[:,2], c=labels)
# Out:
# <Axes: >
