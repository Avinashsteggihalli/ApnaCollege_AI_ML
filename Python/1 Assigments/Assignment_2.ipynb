# %% [markdown]
# # Assignment 2

# %% [markdown]
# ### 1. Write a program that takes salary as input. Using conditional statements, calculate the final tax rate based on the rules:
#
# * if salary < 30,000   --> 5%
# * if salary is 30,000 - 70,000  --> 15%
# * if salary > 70,000   --> 25%

# %%
sal = float(input("Enter the Salary: "))
print("Salary: ",sal)

if sal < 30000:
    rate = sal*(5/100)
    print("Rate of interest: 5%")
    print("\nThe Final Tax Rate: ",rate)

elif sal in range(30000,70001):
    rate = sal*(15/100)
    print("Rate of interest: 15%")
    print("\nThe Final Tax Rate: ",rate)

else:
    rate = sal*(25/100)
    print("Rate of interest: 25%")
    print("\nThe Final Tax Rate: ",rate)
# Out:
# Salary:  85000.0
# Rate of interest: 25%
#
# The Final Tax Rate:  21250.0

# %% [markdown]
# ### 2. Write a function that takes two integer  a and b and prints all even numbers between them(inclusive).

# %%
a = int(input("Integer a: "))
b = int(input("Integer b: "))

print("All even numbers between", a,"and", b," : ")
for i in range(a, b+1):
    if i % 2 == 0:
        print(i)
# Out:
# All even numbers between 2 and 15  :
# 2
# 4
# 6
# 8
# 10
# 12
# 14

# %% [markdown]
# ### 3. Write a function that prints the digits of a number, n.
#
# For e.g. n = 312 , there are 3 digits in it 3,1 and 2 & we need to print them.
#
# [Hint: The right most digit of the number, we can do N = N/10.]

# %%
def digits_of_num(n):
    count = 0
    strg = str(n)
    for i in strg:
        print(int(i))
        count+=1
    print("There are", count, "digits in the given number ")
num = int(input("Enter a number: "))
digits_of_num(num)
# Out:
# 2
# 7
# 3
# 4
# There are 4 digits in the given number

# %% [markdown]
# ### 4. Write a function to return the count the numbers of digits in a number, n.

# %%
def count_num(n):
    count = 0
    strg = str(n)
    for i in strg:
        count+=1
    return count
count_num(4567)
# Out:
# 4

# %% [markdown]
# ### 5. Write a program to return the sum of digits of the numbers, n

# %%
def sum_num_digits(n):
    sum = 0
    strg = str(n)
    for i in strg:
        sum += int(i)
    return sum
sum_num_digits(12)
# Out:
# 3

# %% [markdown]
# ### 6. Write a programme to print all numbers from 1 to 100  that are divisible by both
# 3 and 5

# %%
for i in range(1,101):
    if (i % 3 == 0 and i % 5 == 0):
        print(i)
# Out:
# 15
# 30
# 45
# 60
# 75
# 90

# %% [markdown]
# ### 7. Design a program to continuously input a number n, from the user & print if it is positive or negative until the user enters "Quit".

# %%
user_input = True
while user_input:
    num = (input("\nEnter a number or quit: "))
    if (num == "Quit" or num == "quit"):
        print("\nGood Bye!!")
        user_input = False
    elif int(num) < 0:
        print(num,"is negative Number")
    elif int(num) > 0:
        print(num,"is positive Number")
# Out:
# 23 is positive Number
# -9 is negative Number
#
# Good Bye!!

# %% [markdown]
# ### 8. Let's create a Simple Calculator that performs airthemetic operations . Create a function calculator(a, b, operation) that performs addition, subraction, multiplication or division based on the operation parameter.
#
# [Operation parameter can have values '+', '-' , '*', '/'].

# %%
def Calulator(a, b, operation):
    match (operation):
        case '*':
            print(a*b)
        case '+':
            print(a+b)
        case '-':
            print(a-b)
        case '/':
            print(a/b)    

Calulator(2, 4, '-')
# Out:
# -2

# %% [markdown]
# ### 9. Write a function is_prime(n) that returns True if n is a prime number and False otherwise, using a loop.
#
# [Hint:
# 1. We only check prime for 2 or numbers greater than 2.  2 i smallest prime number .
#
# 2. A non-prime number ,n , will always get divided by atleast one number in range[2,n-1].
#
# Eg- For the number 9 we'll check in range (2,8) & it'll get divided by 3 . So 9 is non prime & prime & we'll return false for it.
#
# For number 7 we'll check in range (2,6) & it won't get divided  by any. So 7 is prime & we'll return True for it.]

# %%
def is_prime(n):
    if n == 2:
        return True
    else:
        for i in range(2,n-1):
            if n % i == 0:
                return False
        return True
num = int(input("Enter a number: "))
print(is_prime(num))
# Out:
# True

# %% [markdown]
# ### 10. Let's create a "Number Guessing Game". Give a secret number (already decided by you), write a pragram that asks the user to guess it and prints.
#
# * "Too high" if the guess is above the number.
# * "Too low" if the guess is below.
# * "Correct!" if the guess match.

# %%
def num_guess(n):
    
        user = int(input("Guess the number: "))
        if n < user:
            return "Too High"
        elif n > user:
            return "Too low"
        else:
            return "Correct Guess"


num = int(input("Enter a number: "))

print(num_guess(num))
# Out:
# Too low
