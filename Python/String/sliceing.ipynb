# %%
word = "I love python"

# %%
single_chr = "'letter'"
multi_char = ''' "more letters" '''
print(single_chr)
print(multi_char)
# Out:
# 'letter'
#  "more letters"

# %%
word[0:13]
# Out:
# 'I love python'

# %%
word[:]
# Out:
# 'I love python'

# %%
word[0:]
# Out:
# 'I love python'

# %%
word[:13]
# Out:
# 'I love python'

# %%
print("last value is")
word[-1]
# Out:
# last value is
# 'n'

# %%
word[2:7]
# Out:
# 'love '

# %%
word
# Out:
# 'I love python'
