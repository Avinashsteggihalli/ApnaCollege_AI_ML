# %%
info = {
    "name" : "Aviansh",
    "Roll no." : "2024wd15148",
    "Subjects" : ["OOPS", "DSA", "P&S", "SP"],
    3.142 : "PI"
}
info
# Out:
# {'name': 'Aviansh',
#  'Roll no.': '2024wd15148',
#  'Subjects': ['OOPS', 'DSA', 'P&S', 'SP'],
#  3.142: 'PI'}

# %%
info["name"]
# Out:
# 'Aviansh'

# %%
info[3.142]
# Out:
# 'PI'

# %%
info["name"][2]
# Out:
# 'i'

# %%
info["name"] = "Avinash S Teggihalli"
info
# Out:
# {'name': 'Avinash S Teggihalli',
#  'Roll no.': '2024wd15148',
#  'Subjects': ['OOPS', 'DSA', 'P&S', 'SP'],
#  3.142: 'PI'}

# %%
info.keys()
# Out:
# dict_keys(['name', 'Roll no.', 'Subjects', 3.142])

# %%
info.values()
# Out:
# dict_values(['Avinash S Teggihalli', '2024wd15148', ['OOPS', 'DSA', 'P&S', 'SP'], 'PI'])

# %%
info.items()
# Out:
# dict_items([('name', 'Avinash S Teggihalli'), ('Roll no.', '2024wd15148'), ('Subjects', ['OOPS', 'DSA', 'P&S', 'SP']), (3.142, 'PI')])

# %%
info.get("Name") #it skips the incorrect key value and think that value is 'None'

# %%
info.get("name")
# Out:
# 'Avinash S Teggihalli'

# %%
info["nme"] #it will show error and stops the excution
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 info["nme"] #it will show error and stops the excution
#
# KeyError: 'nme'

# %%
info.update({
    "city": ["Haveri", "Dwd", "Sirsi", "Bangaluru", "Mysore"]
})
info
# Out:
# {'name': 'Avinash S Teggihalli',
#  'Roll no.': '2024wd15148',
#  'Subjects': ['OOPS', 'DSA', 'P&S', 'SP'],
#  3.142: 'PI',
#  'city': ['Haveri', 'Dwd', 'Sirsi', 'Bangaluru', 'Mysore']}

# %%
info.update({'city':"BGK"})
info
# Out:
# {'name': 'Avinash S Teggihalli',
#  'Roll no.': '2024wd15148',
#  'Subjects': ['OOPS', 'DSA', 'P&S', 'SP'],
#  3.142: 'PI',
#  'city': 'BGK',
#  'placey': 'BGK'}

# %%
l = [1,3,5,6]
info["city"] = l
info
# Out:
# {'name': 'Avinash S Teggihalli',
#  'Roll no.': '2024wd15148',
#  'Subjects': ['OOPS', 'DSA', 'P&S', 'SP'],
#  3.142: 'PI',
#  'city': [1, 3, 5, 6],
#  'placey': 'BGK'}
