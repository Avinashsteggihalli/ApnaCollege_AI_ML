# %%
l = [4,6,8,2,5,1]
l.reverse()
l
# Out:
# [1, 5, 2, 8, 6, 4]

# %%
l.reverse
print(l)
# Out:
# [8, 6, 5, 4, 2, 1]

# %%
l.sort(reverse = True)
l
# Out:
# [8, 6, 5, 4, 2, 1]

# %%
l.sort()
l
# Out:
# [1, 2, 4, 5, 6, 8]

# %%
l.reverse()
l
# Out:
# [8, 6, 5, 4, 2, 1]

# %%
l.append(99) # in list (but in 'set' it is add())
l
# Out:
# [8, 6, 5, 4, 2, 1, 99]

# %%
l.insert(4, 1000) 
l
# Out:
# [8, 6, 5, 4, 1000, 2, 1, 99]
