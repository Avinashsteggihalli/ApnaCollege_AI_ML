# %%
s = {1,2,2,2,3}
s
# Out:
# {1, 2, 3}

# %%
len(s)
# Out:
# 3

# %%
s.add(4) # in set it is s.add() ,but in 'list' it is l.append()
s
# Out:
# {1, 2, 3, 4}

# %%
type(s)
# Out:
# set

# %%
s.remove(2) # removes the cerain value in the set
s
# Out:
# {1, 3, 4}

# %%
s.clear()  # deletes all elements in the set
s
# Out:
# set()

# %%
s1 = {2,2,2,3,3,1,5}
s1
# Out:
# {1, 2, 3, 5}

# %%
s1.pop() # removes a a random value
# Out:
# 1

# %%
s3 = {"s", "s", 's' , 'k', 3, 4}
s3
# Out:
# {3, 4, 'k', 's'}

# %%
print(s3.union(s1)) # combines the the sets and returns the unodered new set
print("unordered elements")
# Out:
# {2, 3, 's', 4, 5, 'k'}
# unordered elements

# %%
print(s1.intersection(s3)) # retruns the common betwen them
# Out:
# {3}
